# %%
import os

import numpy as np
from werkzeug.serving import can_fork

from transform_dataset import *
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Load in Data

# %%
prices = load_dataset('prices.csv')
prices
# Out:
#        ALGO    AENO    LSST    SRNA   ELLT   AMRP   OTCS   HETT   HUXZ   DUCT  \
# 0    100.00  116.51  113.55  134.23  64.12  25.05  14.68  59.24  83.62  19.71
# 1     98.49  112.94  114.53  133.21  62.74  23.96  14.55  58.28  79.94  19.22
# 2     97.83  112.70  112.17  132.80  61.61  23.30  14.69  57.97  81.20  19.22
# 3     98.02  112.26  116.09  133.16  63.55  23.47  14.43  57.02  81.82  19.39
# 4     99.13  113.59  119.58  137.20  63.64  23.61  14.61  58.78  83.01  19.91
# ..      ...     ...     ...     ...    ...    ...    ...    ...    ...    ...
# 995  120.41   78.94  134.18   71.34  77.93  15.30  22.40  83.24  53.75  10.47
# 996  120.93   77.04  135.65   70.20  79.34  15.17  21.90  82.89  54.62  10.67
# 997  120.92   77.59  133.28   70.37  78.65  14.74  22.01  83.08  55.18  10.44
# 998  118.51   77.73  130.24   68.05  77.87  14.64  22.17  81.36  53.43  10.29
# 999  117.16   75.69  128.89   67.92  76.28  14.19  22.80  83.12  55.13  10.24
#
#      ...   BLBT   BENI   ITPA   HTRK   NGTE   ILVX   FCSG   FARS   MHRM   EAFC
# 0    ...  52.23  32.37  18.82  10.86  52.65  32.58  27.46  66.43  22.41  45.08
# 1    ...  52.73  32.25  18.41  10.77  49.71  31.66  26.47  64.66  22.10  44.28
# 2    ...  53.23  32.23  18.22  10.69  50.53  30.84  25.28  64.19  20.87  45.30
# 3    ...  52.67  32.20  18.22  10.28  51.64  30.95  24.60  62.80  20.95  46.32
# 4    ...  53.59  32.33  18.25  10.50  53.57  31.49  25.66  63.94  20.72  45.56
# ..   ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 995  ...  37.02  38.30  28.66  13.90  45.86  67.85  33.19  36.82  17.72  39.49
# 996  ...  36.92  38.00  29.11  13.61  46.57  67.91  33.13  37.51  17.63  39.53
# 997  ...  36.50  37.67  29.76  13.66  45.20  67.62  33.33  37.84  17.40  39.68
# 998  ...  35.95  38.05  28.80  13.48  44.99  67.89  32.70  37.18  17.29  39.12
# 999  ...  36.26  37.65  28.78  13.69  45.09  67.30  31.42  35.71  17.43  39.91
#
# [1000 rows x 51 columns]

# %%
prices.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 51 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ALGO    1000 non-null   float64
#  1   AENO    1000 non-null   float64
#  2   LSST    1000 non-null   float64
#  3   SRNA    1000 non-null   float64
#  4   ELLT    1000 non-null   float64
#  5   AMRP    1000 non-null   float64
#  6   OTCS    1000 non-null   float64
#  7   HETT    1000 non-null   float64
#  8   HUXZ    1000 non-null   float64
#  9   DUCT    1000 non-null   float64
#  10  SMAH    1000 non-null   float64
#  11  NPCK    1000 non-null   float64
#  12  MSDP    1000 non-null   float64
#  13  EORC    1000 non-null   float64
#  14  CUBO    1000 non-null   float64
#  15  HRET    1000 non-null   float64
#  16  ANSO    1000 non-null   float64
#  17  DIHO    1000 non-null   float64
#  18  RTTH    1000 non-null   float64
#  19  SPLZ    1000 non-null   float64
#  20  NWIG    1000 non-null   float64
#  21  MMBT    1000 non-null   float64
#  22  MDGI    1000 non-null   float64
#  23  AGVF    1000 non-null   float64
#  24  RRES    1000 non-null   float64
#  25  CTGI    1000 non-null   float64
#  26  ALUT    1000 non-null   float64
#  27  ACAC    1000 non-null   float64
#  28  SRTX    1000 non-null   float64
#  29  GARI    1000 non-null   float64
#  30  RCRI    1000 non-null   float64
#  31  ACIX    1000 non-null   float64
#  32  CCNS    1000 non-null   float64
#  33  MTNS    1000 non-null   float64
#  34  IHOZ    1000 non-null   float64
#  35  NAYO    1000 non-null   float64
#  36  FWWG    1000 non-null   float64
#  37  EELT    1000 non-null   float64
#  38  HRND    1000 non-null   float64
#  39  AETS    1000 non-null   float64
#  40  ULXY    1000 non-null   float64
#  41  BLBT    1000 non-null   float64
#  42  BENI    1000 non-null   float64
#  43  ITPA    1000 non-null   float64
#  44  HTRK    1000 non-null   float64
#  45  NGTE    1000 non-null   float64
#  46  ILVX    1000 non-null   float64
#  47  FCSG    1000 non-null   float64
#  48  FARS    1000 non-null   float64
#  49  MHRM    1000 non-null   float64
#  50  EAFC    1000 non-null   float64
# dtypes: float64(51)
# memory usage: 398.6 KB

# %%
print(prices.describe())
# Out:
#               ALGO         AENO         LSST         SRNA         ELLT  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean     96.103300    81.232130    90.612370    87.547430    77.716300
# std       9.197768    22.292651    14.674314    32.012435    19.465857
# min      77.200000    52.500000    61.730000    48.390000    42.520000
# 25%      88.220000    62.660000    80.440000    59.157500    64.455000
# 50%      97.480000    74.285000    87.255000    75.230000    73.325000
# 75%     103.685000   101.445000    97.440000   115.272500    94.305000
# max     120.930000   133.520000   140.530000   166.260000   123.030000
#
#              AMRP         OTCS         HETT         HUXZ        DUCT  ...  \
# count  1000.00000  1000.000000  1000.000000  1000.000000  1000.00000  ...
# mean     17.98691    23.835750    66.992570    60.665350    15.12207  ...
# std       3.19974     6.320389     9.844589    13.654475     3.91003  ...
# min      11.55000    12.610000    46.540000    42.430000     9.95000  ...
# 25%      15.62000    19.207500    60.147500    50.127500    12.23750  ...
# 50%      16.88000    23.580000    65.805000    54.610000    13.41500  ...
# 75%      20.58000    28.530000    73.382500    71.320000    18.20500  ...
# max      26.23000    40.680000    95.690000    96.600000    27.35000  ...
#
#               BLBT         BENI         ITPA         HTRK         NGTE  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean     36.870890    28.357160    24.268040    11.512230    47.855360
# std       7.646569     4.021312     2.502863     1.380796    15.094101
# min      24.140000    23.820000    17.940000     8.320000    27.370000
# 25%      30.022500    25.535000    22.567500    10.590000    34.587500
# 50%      35.480000    27.230000    24.560000    11.320000    45.600000
# 75%      44.372500    29.470000    25.870000    12.520000    56.737500
# max      56.180000    40.970000    30.240000    14.890000    85.840000
#
#               ILVX         FCSG         FARS         MHRM         EAFC
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean     45.455610    28.252270    38.395370    14.383350    28.515930
# std       9.720789     5.890051     7.843147     3.806981     7.842248
# min      30.840000    16.380000    26.650000     7.330000    14.980000
# 25%      37.040000    24.065000    33.190000    11.455000    22.337500
# 50%      44.080000    27.460000    35.715000    14.465000    28.015000
# 75%      52.617500    32.070000    40.472500    17.792500    35.590000
# max      68.200000    43.690000    66.430000    22.410000    46.420000
#
# [8 rows x 51 columns]

# %% [markdown]
# Per Instrument Summary Stats:

# %%
for instruments in prices.columns:
    mean = prices[instruments].mean()
    std = prices[instruments].std()
    var = std**2
    median = prices[instruments].median()
    skew = prices[instruments].skew()
    kurtosis = prices[instruments].kurtosis()
    print(f"Instrument Name: {instruments}\n"
          f"Mean: {mean}\n"
          f"Std: {std}\n"
          f"Median : {median}\n"
          f"Std / Mean: {std/mean}\n"
          f"Variance: {var}\n"
          f"Skew: {skew}\n"
          f"Kurtosis: {kurtosis}\n")
# Out:
# Instrument Name: ALGO
# Mean: 96.10329999999999
# Std: 9.197768188514521
# Median : 97.48
# Std / Mean: 0.09570710046912564
# Variance: 84.5989396496497
# Skew: 0.03872519205804018
# Kurtosis: -0.8637958775274552
#
# Instrument Name: AENO
# Mean: 81.23213
# Std: 22.29265064625417
# Median : 74.285
# Std / Mean: 0.274431442906325
# Variance: 496.96227283593646
# Skew: 0.7515861492603226
# Kurtosis: -0.7969684640467416
#
# Instrument Name: LSST
# Mean: 90.61237
# Std: 14.674313904631855
# Median : 87.255
# Std / Mean: 0.16194603346796752
# Variance: 215.33548857167182
# Skew: 1.1068019517666072
# Kurtosis: 0.9357417391256742
#
# Instrument Name: SRNA
# Mean: 87.54742999999999
# Std: 32.012435035342
# Median : 75.23
# Std / Mean: 0.3656581927686741
# Variance: 1024.795996891992
# Skew: 0.609375221621717
# Kurtosis: -0.8765627462279455
#
# Instrument Name: ELLT
# Mean: 77.71629999999999
# Std: 19.46585749248971
# Median : 73.325
# Std / Mean: 0.250473291863994
# Variance: 378.9196079179178
# Skew: 0.40941414092625894
# Kurtosis: -0.7546358263965787
#
# Instrument Name: AMRP
# Mean: 17.986909999999998
# Std: 3.199739690347641
# Median : 16.88
# Std / Mean: 0.17789268364314056
# Variance: 10.238334085986017
# Skew: 0.4701591052577209
# Kurtosis: -0.7769953080451164
#
# Instrument Name: OTCS
# Mean: 23.83575
# Std: 6.320389383531642
# Median : 23.58
# Std / Mean: 0.2651642756586909
# Variance: 39.94732195945949
# Skew: 0.2703791439780408
# Kurtosis: -0.7363648997579428
#
# Instrument Name: HETT
# Mean: 66.99257
# Std: 9.844589480376372
# Median : 65.805
# Std / Mean: 0.14695046749775942
# Variance: 96.91594203713714
# Skew: 0.3874249285375278
# Kurtosis: -0.28028545383524106
#
# Instrument Name: HUXZ
# Mean: 60.66535
# Std: 13.654474612904545
# Median : 54.61
# Std / Mean: 0.22507864230412494
# Variance: 186.44467695445474
# Skew: 0.8033689704764968
# Kurtosis: -0.63123082628349
#
# Instrument Name: DUCT
# Mean: 15.122069999999999
# Std: 3.910030070248851
# Median : 13.415
# Std / Mean: 0.25856447366325186
# Variance: 15.288335150250235
# Skew: 0.9917350486351711
# Kurtosis: -0.007511524277646675
#
# Instrument Name: SMAH
# Mean: 61.89005
# Std: 13.674557258416588
# Median : 61.72
# Std / Mean: 0.22094920360246253
# Variance: 186.99351621371378
# Skew: 0.4061296536972725
# Kurtosis: -0.7944241123426128
#
# Instrument Name: NPCK
# Mean: 9.238209999999999
# Std: 2.97766102185273
# Median : 8.16
# Std / Mean: 0.32232012715155106
# Variance: 8.866465161061045
# Skew: 1.2153566300180523
# Kurtosis: 0.5122671972040038
#
# Instrument Name: MSDP
# Mean: 28.035729999999997
# Std: 6.210220471561813
# Median : 26.805
# Std / Mean: 0.22151092450818344
# Variance: 38.56683830540543
# Skew: 0.2926482041250449
# Kurtosis: -0.6734687218347295
#
# Instrument Name: EORC
# Mean: 28.95666
# Std: 9.02692957222454
# Median : 26.985
# Std / Mean: 0.3117393225677458
# Variance: 81.48545750190193
# Skew: 0.6968532601363117
# Kurtosis: -0.5183149455127283
#
# Instrument Name: CUBO
# Mean: 162.1892
# Std: 28.082299754819225
# Median : 166.485
# Std / Mean: 0.17314531272624334
# Variance: 788.6155595195199
# Skew: -0.05773397716870953
# Kurtosis: -0.9509288373657117
#
# Instrument Name: HRET
# Mean: 50.676410000000004
# Std: 7.4772407170453326
# Median : 48.93
# Std / Mean: 0.14754874540334115
# Variance: 55.9091287406406
# Skew: 0.45959833914084564
# Kurtosis: -0.9581351773240838
#
# Instrument Name: ANSO
# Mean: 53.764509999999994
# Std: 7.3149577556447145
# Median : 53.44
# Std / Mean: 0.1360555086551466
# Variance: 53.50860696686676
# Skew: 0.29749890446111543
# Kurtosis: -0.5197617836227328
#
# Instrument Name: DIHO
# Mean: 9.368759999999998
# Std: 2.313934042524367
# Median : 9.45
# Std / Mean: 0.2469840237688197
# Variance: 5.354290753153158
# Skew: 0.02453916471512118
# Kurtosis: -1.1070783390210013
#
# Instrument Name: RTTH
# Mean: 28.196879999999997
# Std: 8.615242461374393
# Median : 28.905
# Std / Mean: 0.3055388561207621
# Variance: 74.22240266826832
# Skew: 0.3451462799809639
# Kurtosis: -0.9771936517361897
#
# Instrument Name: SPLZ
# Mean: 66.21099
# Std: 25.286614146122336
# Median : 58.32
# Std / Mean: 0.381909621742891
# Variance: 639.4128549748742
# Skew: 0.33927421016061426
# Kurtosis: -1.1520930023423306
#
# Instrument Name: NWIG
# Mean: 86.77225
# Std: 24.181027466318042
# Median : 79.38
# Std / Mean: 0.2786723574220796
# Variance: 584.7220893268276
# Skew: 0.8120016001634459
# Kurtosis: -0.5781141456202361
#
# Instrument Name: MMBT
# Mean: 221.37978
# Std: 115.90239317155833
# Median : 184.48000000000002
# Std / Mean: 0.5235455251222958
# Variance: 13433.364742894491
# Skew: 1.5822502481986198
# Kurtosis: 4.49393560851685
#
# Instrument Name: MDGI
# Mean: 228.63431
# Std: 42.514268736155756
# Median : 230.1
# Std / Mean: 0.18594877005186036
# Variance: 1807.4630461700708
# Skew: 0.15159768816105607
# Kurtosis: 0.45591303388897186
#
# Instrument Name: AGVF
# Mean: 104.29854
# Std: 18.900887884732573
# Median : 106.42500000000001
# Std / Mean: 0.18121910320827667
# Variance: 357.2435628312305
# Skew: -0.24466219625849112
# Kurtosis: -0.8094686722322857
#
# Instrument Name: RRES
# Mean: 48.9423
# Std: 8.59981940530171
# Median : 47.66
# Std / Mean: 0.17571343000434614
# Variance: 73.95689380380387
# Skew: 0.43905259314797
# Kurtosis: -0.6377410486234409
#
# Instrument Name: CTGI
# Mean: 101.56885
# Std: 18.093325465593775
# Median : 99.465
# Std / Mean: 0.17813852835385824
# Variance: 327.3684264039042
# Skew: 0.17008881753068406
# Kurtosis: -0.6199752728812573
#
# Instrument Name: ALUT
# Mean: 13.65788
# Std: 3.1400288990847005
# Median : 13.325
# Std / Mean: 0.22990602487975442
# Variance: 9.859781487087076
# Skew: 0.4534686004286304
# Kurtosis: -0.5742160419667091
#
# Instrument Name: ACAC
# Mean: 54.79273999999999
# Std: 11.951764420585143
# Median : 50.724999999999994
# Std / Mean: 0.2181267887056779
# Variance: 142.84467276516492
# Skew: 0.7143976378335234
# Kurtosis: -0.7678264179742271
#
# Instrument Name: SRTX
# Mean: 242.9062
# Std: 54.15668278661876
# Median : 251.375
# Std / Mean: 0.22295306907200704
# Variance: 2932.9462904504485
# Skew: -0.06979601589070215
# Kurtosis: -1.241972959496237
#
# Instrument Name: GARI
# Mean: 10.23617
# Std: 3.2526264171757733
# Median : 9.635000000000002
# Std / Mean: 0.31775814754696075
# Variance: 10.579578609709708
# Skew: 0.5078382729628395
# Kurtosis: -0.9935163267368563
#
# Instrument Name: RCRI
# Mean: 39.99571
# Std: 10.393501949712554
# Median : 40.11
# Std / Mean: 0.25986541930903473
# Variance: 108.02488277867867
# Skew: 0.12406273266612913
# Kurtosis: -0.8392225091630068
#
# Instrument Name: ACIX
# Mean: 20.07028
# Std: 2.1230138269237226
# Median : 20.015
# Std / Mean: 0.1057789839964227
# Variance: 4.50718770930931
# Skew: 0.012031249490782719
# Kurtosis: -0.4889372949882054
#
# Instrument Name: CCNS
# Mean: 17.21086
# Std: 4.453984153006751
# Median : 16.619999999999997
# Std / Mean: 0.2587891687577931
# Variance: 19.83797483523527
# Skew: 0.4768534043297344
# Kurtosis: -0.9044643798478784
#
# Instrument Name: MTNS
# Mean: 20.3449
# Std: 3.1212351559757394
# Median : 19.5
# Std / Mean: 0.15341609720252936
# Variance: 9.742108898898898
# Skew: 1.3907766337215963
# Kurtosis: 1.232711584597102
#
# Instrument Name: IHOZ
# Mean: 121.46966
# Std: 18.292550387632776
# Median : 119.475
# Std / Mean: 0.15059357528153758
# Variance: 334.61739968408403
# Skew: 0.26245577594283515
# Kurtosis: -1.0346801450317047
#
# Instrument Name: NAYO
# Mean: 26.316489999999998
# Std: 7.695077790516619
# Median : 27.265
# Std / Mean: 0.2924051722139472
# Variance: 59.21422220210213
# Skew: 0.1087698383456228
# Kurtosis: -1.3653449446265606
#
# Instrument Name: FWWG
# Mean: 27.26974
# Std: 5.580076091020769
# Median : 26.34
# Std / Mean: 0.20462520328469463
# Variance: 31.137249181581623
# Skew: 0.236393499350537
# Kurtosis: -1.2262108857340355
#
# Instrument Name: EELT
# Mean: 96.24719999999999
# Std: 16.864935149522427
# Median : 95.89
# Std / Mean: 0.17522520291003196
# Variance: 284.42603759759703
# Skew: 0.023209594642620977
# Kurtosis: 0.19249224177434732
#
# Instrument Name: HRND
# Mean: 18.5148
# Std: 8.384284691599495
# Median : 17.845
# Std / Mean: 0.45284230408103215
# Variance: 70.29622978978963
# Skew: 0.3290551983241319
# Kurtosis: -0.8955247751289535
#
# Instrument Name: AETS
# Mean: 28.151510000000002
# Std: 6.570040445183834
# Median : 27.285
# Std / Mean: 0.23338145787504236
# Variance: 43.165431451351395
# Skew: 0.4639747549514412
# Kurtosis: 0.13555549219313212
#
# Instrument Name: ULXY
# Mean: 50.26984999999999
# Std: 7.330063048964983
# Median : 49.805
# Std / Mean: 0.14581430119574626
# Variance: 53.72982430180183
# Skew: 0.30474346841566907
# Kurtosis: -0.283365478429737
#
# Instrument Name: BLBT
# Mean: 36.87089
# Std: 7.646569121326713
# Median : 35.48
# Std / Mean: 0.20738770128214187
# Variance: 58.47001932722718
# Skew: 0.284384331537103
# Kurtosis: -1.0199622688851053
#
# Instrument Name: BENI
# Mean: 28.35716
# Std: 4.021311861007982
# Median : 27.23
# Std / Mean: 0.1418094005537925
# Variance: 16.17094908348348
# Skew: 1.5863207000003086
# Kurtosis: 1.7479927891702718
#
# Instrument Name: ITPA
# Mean: 24.26804
# Std: 2.502862577026448
# Median : 24.56
# Std / Mean: 0.10313410465066186
# Variance: 6.264321079479472
# Skew: -0.2832280798053918
# Kurtosis: -0.1916176397502265
#
# Instrument Name: HTRK
# Mean: 11.512229999999999
# Std: 1.3807964824788728
# Median : 11.32
# Std / Mean: 0.11994170395126512
# Variance: 1.906598926026028
# Skew: 0.16865608039117386
# Kurtosis: -0.42563048503660417
#
# Instrument Name: NGTE
# Mean: 47.85536
# Std: 15.094101263850161
# Median : 45.6
# Std / Mean: 0.31541088111864923
# Variance: 227.83189296336303
# Skew: 0.6530390355886914
# Kurtosis: -0.6441546013717798
#
# Instrument Name: ILVX
# Mean: 45.45561
# Std: 9.720788731448772
# Median : 44.08
# Std / Mean: 0.21385234366998424
# Variance: 94.49373356146144
# Skew: 0.3848901269101396
# Kurtosis: -1.0144697640419043
#
# Instrument Name: FCSG
# Mean: 28.25227
# Std: 5.890050784615136
# Median : 27.46
# Std / Mean: 0.208480620658628
# Variance: 34.692698245345376
# Skew: 0.29083073459463765
# Kurtosis: -0.6110731904791762
#
# Instrument Name: FARS
# Mean: 38.39537
# Std: 7.843146575916532
# Median : 35.715
# Std / Mean: 0.20427323856799745
# Variance: 61.51494821131122
# Skew: 1.355765924540264
# Kurtosis: 1.3005310258597755
#
# Instrument Name: MHRM
# Mean: 14.383349999999998
# Std: 3.8069814532363133
# Median : 14.465
# Std / Mean: 0.26467974798891175
# Variance: 14.493107785285272
# Skew: -0.1312715586334064
# Kurtosis: -1.1640063800461125
#
# Instrument Name: EAFC
# Mean: 28.51593
# Std: 7.842247763561487
# Median : 28.015
# Std / Mean: 0.275012870474906
# Variance: 61.500849985085146
# Skew: 0.09720726401139454
# Kurtosis: -1.0660737174464465

# %% [markdown]
# Price Distribution Plots

# %%
for instruments in prices.columns:
    plt.figure(figsize=(8,8))
    plt.hist(prices[instruments], edgecolor='black', bins=20)
    plt.title(instruments)
    plt.xlabel('price')
    plt.ylabel('count')
    plt.show()

# %% [markdown]
# SPLZ seems to be normally distributed mainly, BENI is bimodal and looking at its price data, seems to have a regime shift.  Seems that multiple peaks are indicative of regime shifts, so going to have to find a way to combat that regime shift somehow, and detect its onset.  Perhaps the key to regime shift detection is in other instruments

# %% [markdown]
# Prices Vs Time
#
# On The Plotly Express Plots file, will create an HTML for easier observation

# %% [markdown]
# ADF Test, checks for stationarity, results are on ADF_ACF_tests script, notebook had an issue:
# For ADF Test: the following stocks were interesting and had notable results:
# For constant regression component used:
# MTNS, NAYO, EELT, ULXY, BENI.
# For constant and trend regression component used (stationary around a trending mean):
# NAYO, MTNS, GARI, RTTH

# %% [markdown]
# NAYO seems to be mean reverting around some moving/trending target while MTNS is mean reverting around some constant mean.

# %%
matrix1 = np.log(prices).corr('spearman')
plt.figure(figsize=(20,20))
sns.heatmap(data=matrix1, cmap='coolwarm', vmin=-1, vmax=1)
# Out:
# <Axes: >

# %%
matrix2 = np.log(prices).corr('pearson')
plt.figure(figsize=(20,20))
sns.heatmap(data=matrix2, cmap='coolwarm', vmin=-1, vmax=1)
# Out:
# <Axes: >

# %% [markdown]
# lagged dcorr (5 days)

# %%
dcorr_df = pd.read_csv('dcorr_df_no_algo.csv')
from scipy.spatial.distance import squareform
import pandas as pd

condensed = dcorr_df.sort_values(['instrument_1', 'instrument_2_shifted'])['distance_corr'].values
dcorr_matrix = squareform(condensed)
n = 50
dcorr_df_square = pd.DataFrame(dcorr_matrix,
                                 index=[f'{prices.columns.values[k]}' for k in range(1,n+1)],
                                 columns=[f'{prices.columns.values[k]}' for k in range(1,n+1)])

np.fill_diagonal(dcorr_matrix, 1.0)
plt.figure(figsize=(20,20))
sns.heatmap(dcorr_df_square, cmap='coolwarm', square=True)
# Out:
# <Axes: >

# %%
dcorr_returns = pd.read_csv('dcorr_no_lag.csv')
condensed = dcorr_returns.sort_values(['instrument_1', 'instrument_2_shifted'])['distance_corr'].values
dcorr_matrix = squareform(condensed)
n = 51
dcorr_df_square = pd.DataFrame(dcorr_matrix,
                                 index=[f'{prices.columns.values[k]}' for k in range(n)],
                                 columns=[f'{prices.columns.values[k]}' for k in range(n)])

np.fill_diagonal(dcorr_matrix, 1.0)
plt.figure(figsize=(20,20))
sns.heatmap(dcorr_df_square, cmap='coolwarm', square=True, vmin=0.0, vmax=1.0)
# Out:
# <Axes: >

# %%
dcorr_returns = pd.read_csv('dcorr_resids.csv')
dcorr_matrix = dcorr_returns.pivot(index='instrument_1', columns='instrument_2', values='distance_corr')
n = 50
dcorr_df_square = pd.DataFrame(dcorr_matrix,
                                 index=[f'{prices.columns.values[k]}' for k in range(1,n+1)],
                                 columns=[f'{prices.columns.values[k]}' for k in range(1,n+1)])
dcorr_matrix.index = [f'{prices.columns.values[k]}' for k in range(1,n+1)]
dcorr_matrix.columns = [f'{prices.columns.values[k]}' for k in range(1,n+1)]

plt.figure(figsize=(20,20))
sns.heatmap(dcorr_matrix, cmap='coolwarm', square=True, vmin=0.0, vmax=1.0)
# Out:
# <Axes: >

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import signal

prices = np.log(pd.read_csv("prices.csv").iloc[:500])

for a in prices.columns:
    # Use returns rather than prices
    x = prices[a].to_numpy()
    y = prices['MMBT'].to_numpy()

    # Remove the mean
    x = x - np.mean(x)
    y = y - np.mean(y)

    # Compute normalized cross-correlation
    corr = signal.correlate(x, y, mode="full")
    lags = signal.correlation_lags(len(x), len(y), mode="full")
    corr = corr / (len(x) * np.std(x) * np.std(y))

    # Find the strongest correlation (positive or negative)
    idx = np.argmax(np.abs(corr))

    print(f"{a} vs MHRM")
    print(f"Best lag: {lags[idx]}")
    print(f"Correlation: {corr[idx]:.4f}")

    if lags[idx] > 0:
        print(f"→ MMBT leads {a} by {lags[idx]} days")
    elif lags[idx] < 0:
        print(f"→ {a} leads MMBT by {-lags[idx]} days")
    else:
        print("→ No lead-lag relationship (peak at lag 0)")

    # plt.figure(figsize=(8, 4))
    # plt.plot(lags, corr)
    # plt.axvline(0, color="black", linestyle="--")
    # plt.axhline(0, color="grey", linestyle=":")
    # plt.title(f"Cross-correlation: {a} vs MMBT")
    # plt.xlabel("Lag (days)")
    # plt.ylabel("Normalized cross-correlation")
    # plt.grid(True)
    # plt.show()
# Out:
# ALGO vs MHRM
# Best lag: 229
# Correlation: -0.5187
# → MMBT leads ALGO by 229 days
# AENO vs MHRM
# Best lag: 94
# Correlation: -0.7004
# → MMBT leads AENO by 94 days
# LSST vs MHRM
# Best lag: -57
# Correlation: -0.6215
# → LSST leads MMBT by 57 days
# SRNA vs MHRM
# Best lag: 136
# Correlation: -0.6440
# → MMBT leads SRNA by 136 days
# ELLT vs MHRM
# Best lag: -44
# Correlation: 0.6395
# → ELLT leads MMBT by 44 days
# AMRP vs MHRM
# Best lag: 14
# Correlation: -0.8481
# → MMBT leads AMRP by 14 days
# OTCS vs MHRM
# Best lag: 0
# Correlation: 0.7657
# → No lead-lag relationship (peak at lag 0)
# HETT vs MHRM
# Best lag: 161
# Correlation: 0.3721
# → MMBT leads HETT by 161 days
# HUXZ vs MHRM
# Best lag: 114
# Correlation: -0.5827
# → MMBT leads HUXZ by 114 days
# DUCT vs MHRM
# Best lag: 94
# Correlation: -0.7085
# → MMBT leads DUCT by 94 days
# SMAH vs MHRM
# Best lag: 22
# Correlation: 0.7967
# → MMBT leads SMAH by 22 days
# NPCK vs MHRM
# Best lag: 0
# Correlation: -0.6758
# → No lead-lag relationship (peak at lag 0)
# MSDP vs MHRM
# Best lag: 0
# Correlation: -0.6622
# → No lead-lag relationship (peak at lag 0)
# EORC vs MHRM
# Best lag: 229
# Correlation: -0.5897
# → MMBT leads EORC by 229 days
# CUBO vs MHRM
# Best lag: 116
# Correlation: 0.6485
# → MMBT leads CUBO by 116 days
# HRET vs MHRM
# Best lag: 212
# Correlation: -0.5729
# → MMBT leads HRET by 212 days
# ANSO vs MHRM
# Best lag: 72
# Correlation: 0.7624
# → MMBT leads ANSO by 72 days
# DIHO vs MHRM
# Best lag: 366
# Correlation: 0.4191
# → MMBT leads DIHO by 366 days
# RTTH vs MHRM
# Best lag: -51
# Correlation: -0.6111
# → RTTH leads MMBT by 51 days
# SPLZ vs MHRM
# Best lag: 371
# Correlation: 0.4620
# → MMBT leads SPLZ by 371 days
# NWIG vs MHRM
# Best lag: 93
# Correlation: -0.7043
# → MMBT leads NWIG by 93 days
# MMBT vs MHRM
# Best lag: 0
# Correlation: 1.0000
# → No lead-lag relationship (peak at lag 0)
# MDGI vs MHRM
# Best lag: -66
# Correlation: 0.5886
# → MDGI leads MMBT by 66 days
# AGVF vs MHRM
# Best lag: 366
# Correlation: 0.5726
# → MMBT leads AGVF by 366 days
# RRES vs MHRM
# Best lag: 0
# Correlation: 0.6565
# → No lead-lag relationship (peak at lag 0)
# CTGI vs MHRM
# Best lag: 0
# Correlation: 0.6140
# → No lead-lag relationship (peak at lag 0)
# ALUT vs MHRM
# Best lag: 0
# Correlation: -0.5749
# → No lead-lag relationship (peak at lag 0)
# ACAC vs MHRM
# Best lag: 115
# Correlation: -0.5564
# → MMBT leads ACAC by 115 days
# SRTX vs MHRM
# Best lag: 90
# Correlation: -0.5942
# → MMBT leads SRTX by 90 days
# GARI vs MHRM
# Best lag: 4
# Correlation: -0.7246
# → MMBT leads GARI by 4 days
# RCRI vs MHRM
# Best lag: -49
# Correlation: -0.5741
# → RCRI leads MMBT by 49 days
# ACIX vs MHRM
# Best lag: -39
# Correlation: 0.6327
# → ACIX leads MMBT by 39 days
# CCNS vs MHRM
# Best lag: 79
# Correlation: -0.5298
# → MMBT leads CCNS by 79 days
# MTNS vs MHRM
# Best lag: -33
# Correlation: -0.4729
# → MTNS leads MMBT by 33 days
# IHOZ vs MHRM
# Best lag: 113
# Correlation: -0.6796
# → MMBT leads IHOZ by 113 days
# NAYO vs MHRM
# Best lag: -24
# Correlation: -0.3675
# → NAYO leads MMBT by 24 days
# FWWG vs MHRM
# Best lag: 113
# Correlation: -0.5436
# → MMBT leads FWWG by 113 days
# EELT vs MHRM
# Best lag: -11
# Correlation: 0.5318
# → EELT leads MMBT by 11 days
# HRND vs MHRM
# Best lag: 114
# Correlation: -0.6862
# → MMBT leads HRND by 114 days
# AETS vs MHRM
# Best lag: 178
# Correlation: -0.5246
# → MMBT leads AETS by 178 days
# ULXY vs MHRM
# Best lag: 293
# Correlation: -0.3987
# → MMBT leads ULXY by 293 days
# BLBT vs MHRM
# Best lag: 2
# Correlation: -0.5446
# → MMBT leads BLBT by 2 days
# BENI vs MHRM
# Best lag: -50
# Correlation: -0.6907
# → BENI leads MMBT by 50 days
# ITPA vs MHRM
# Best lag: -45
# Correlation: 0.6711
# → ITPA leads MMBT by 45 days
# HTRK vs MHRM
# Best lag: -57
# Correlation: 0.4601
# → HTRK leads MMBT by 57 days
# NGTE vs MHRM
# Best lag: 229
# Correlation: -0.6150
# → MMBT leads NGTE by 229 days
# ILVX vs MHRM
# Best lag: 25
# Correlation: 0.7860
# → MMBT leads ILVX by 25 days
# FCSG vs MHRM
# Best lag: 0
# Correlation: 0.7319
# → No lead-lag relationship (peak at lag 0)
# FARS vs MHRM
# Best lag: 0
# Correlation: -0.7154
# → No lead-lag relationship (peak at lag 0)
# MHRM vs MHRM
# Best lag: 92
# Correlation: -0.5891
# → MMBT leads MHRM by 92 days
# EAFC vs MHRM
# Best lag: 92
# Correlation: -0.6217
# → MMBT leads EAFC by 92 days

# %% [markdown]
# Price Level PCA

# %%
from sklearn.decomposition import PCA, KernelPCA

pca = KernelPCA(
    n_components=None, kernel="poly", gamma=10, fit_inverse_transform=True, alpha=0.1
)
pca.fit(np.log(prices))
print(f"Entire price series variance ratio: {pca.explained_variance_ratio_}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[96], line 7
#       3 pca = KernelPCA(
#       4     n_components=None, kernel="poly", gamma=10, fit_inverse_transform=True, alpha=0.1
#       5 )
#       6 pca.fit(np.log(prices))
# ----> 7 print(f"Entire price series variance ratio: {pca.explained_variance_ratio_}")
#
# AttributeError: 'KernelPCA' object has no attribute 'explained_variance_ratio_'

# %%
loadings = pca.components_.T
loading_df = pd.DataFrame(data=loadings, columns=[f"PC{i}" for i in range(1,9)], index=prices.columns)
print(loading_df)

# %%
for i in range(1,9):
    pc = loading_df[f'PC{i}'].sort_values(ascending=False)
    print(f'PC{i}')
    print(pc.head())
    print()

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

normalised_prices = scaler.fit_transform(prices)
scores = pca.fit_transform(normalised_prices)
